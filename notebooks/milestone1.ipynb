# %% [markdown]
# # Importação do dataset e análise da qualidade inicial dos dados¶
#
# (Rita Vinagreiro)

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/mpwolke/cusersmarildownloadsgermancsv/german.csv

# %%
df = pd.read_csv("/kaggle/input/datasets/mpwolke/cusersmarildownloadsgermancsv/german.csv", sep=";")
df.head()
# Out:
#    Creditability  Account_Balance  Duration_of_Credit_monthly  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment_Status_of_Previous_Credit  Purpose  Credit_Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value_Savings_Stocks  Length_of_current_employment  Instalment_per_cent  \
# 0                     1                             2                    4
# ...

# %% [markdown]
# # Identificação do tipo de variáveis
#
# (Rita Vinagreiro)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   int64
#  1   Account_Balance                    1000 non-null   int64
#  2   Duration_of_Credit_monthly         1000 non-null   int64
#  3   Payment_Status_of_Previous_Credit  1000 non-null   int64
#  4   Purpose                            1000 non-null   int64
#  5   Credit_Amount                      1000 non-null   int64
#  6   Value_Savings_Stocks               1000 non-null   int64
#  7   Length_of_current_employment       1000 non-null   int64
#  8   Instalment_per_cent                1000 non-null   int64
#  9   Sex_Marital_Status                 1000 non-null   int64
#  10  Guarantors                         1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Creditability  Account_Balance  Duration_of_Credit_monthly  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment_Status_of_Previous_Credit      Purpose  Credit_Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# ...

# %% [markdown]
# # Verificação de nulos
# (Rita Vinagreiro)

# %%
df.isnull().sum()
# Out:
# Creditability                        0
# Account_Balance                      0
# Duration_of_Credit_monthly           0
# Payment_Status_of_Previous_Credit    0
# Purpose                              0
# Credit_Amount                        0
# Value_Savings_Stocks                 0
# Length_of_current_employment         0
# Instalment_per_cent                  0
# Sex_Marital_Status                   0
# Guarantors                           0
# Duration_in_Current_address          0
# Most_valuable_available_asset        0
# Age_years                            0
# Concurrent_Credits                   0
# Type_of_apartment                    0
# No_of_Credits_at_this_Bank           0
# Occupation                           0
# No_of_dependents                     0
# Telephone                            0
# Foreign_Worker                       0
# dtype: int64

# %% [markdown]
# # Distribuição da variável alvo
#
# (Rita Vinagreiro)

# %%
# Contagem da variável alvo
print(df['Creditability'].value_counts())

# Percentagens
print(df['Creditability'].value_counts(normalize=True) * 100)

# Gráfico
sns.countplot(x='Creditability', data=df)
plt.title('Distribuição da Variável Alvo')
plt.show()
# Out:
# Creditability
# 1    700
# 0    300
# Name: count, dtype: int64
# Creditability
# 1    70.0
# 0    30.0
# Name: proportion, dtype: float64

# %% [markdown]
# # Conclusão de notebook
#     Após esta pequena análise inicial, podemos concluir que o *dataset* não apresenta valores nulos, no entanto, este tópico será explorado num *Milestone* a posteriori. Além disso, verificou-se que a variável alvo apresenta uma distribuição desequilibrada de 30% (mau crédito)/70% (bom crédito).
